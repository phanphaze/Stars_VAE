# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics = np.load("../metrics.npz",allow_pickle=True)

# %%
metrics.keys()
# Out:
# KeysView(NpzFile '../metrics.npz' with keys: train_mse, train_kld, train_pde, val_mse, val_kld...)

# %%
plt.plot(metrics["train_mse"])

# %%
cd ..
# Out:
# /u/fatimasyed7/fatimasyed7/Stars_VAE
