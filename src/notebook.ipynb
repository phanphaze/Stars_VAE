# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics = np.load("../metrics.npz",allow_pickle=True)

# %%
metrics.keys()
# Out:
# KeysView(NpzFile '../metrics.npz' with keys: train_mse, train_kld, val_mse, val_kld, total_val_loss)

# %%
plt.plot(metrics["train_mse"])
